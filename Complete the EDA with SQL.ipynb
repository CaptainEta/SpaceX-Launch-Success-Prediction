# %%
# !pip install sqlalchemy==1.3.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 127.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... one
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp312-cp312-linux_x86_64.whl size=1160111 sha256=5f5fc2639e836c5f6d32822b2c39f4eb6e7aa3c541100cf0d5f1e1b9892a0bf6
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/b3/1c/42/0e26b8d512adc6bce10ff71a05229366b4ccec641cd3b42111
# Successfully built sqlalchemy
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.37
#     Uninstalling SQLAlchemy-2.0.37:
#       Successfully uninstalled SQLAlchemy-2.0.37
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterhub 5.2.1 requires SQLAlchemy>=1.4.1, but you have sqlalchemy 1.3.9 which is incompatible.
# ...

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 139.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.9
#     Uninstalling SQLAlchemy-1.3.9:
#       Successfully uninstalled SQLAlchemy-1.3.9
# ...

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %%
# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql SELECT DISTINCT "LaunchSite" FROM SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('LaunchSite',)]

# %%
# %sql SELECT * FROM SPACEXTBL WHERE "LaunchSite" LIKE 'CCA%' LIMIT 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql SELECT SUM("PayloadMass") AS total_payload_mass FROM SPACEXTBL WHERE "Customer" = 'NASA (CRS)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(0.0,)]

# %%
# %sql SELECT AVG("PayloadMass") AS avg_payload_mass FROM SPACEXTBL WHERE "BoosterVersion" = 'F9 v1.1';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(None,)]

# %%
# %sql SELECT MIN("Date") FROM SPACEXTBL WHERE "Outcome" = 'True RTLS';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(None,)]

# %%
# %sql SELECT DISTINCT "BoosterVersion" FROM SPACEXTBL WHERE "Outcome" = 'True ASDS' AND "PayloadMass" BETWEEN 4001 AND 5999;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql SELECT "Outcome", COUNT(*) AS count FROM SPACEXTBL GROUP BY "Outcome";
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Outcome', 101)]

# %%
# %sql SELECT DISTINCT "BoosterVersion" FROM SPACEXTBL WHERE "PayloadMass" = (SELECT MAX("PayloadMass") FROM SPACEXTBL);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('BoosterVersion',)]

# %%
# %sql SELECT substr("Date",6,2) AS month, "BoosterVersion", "LaunchSite", "Outcome" FROM SPACEXTBL WHERE substr("Date",1,4) = '2015' AND "Outcome" LIKE 'False ASDS';
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql SELECT "Outcome", COUNT(*) AS count FROM SPACEXTBL WHERE "Date" BETWEEN '2010-06-04' AND '2017-03-20' GROUP BY "Outcome" ORDER BY count DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Outcome', 31)]
